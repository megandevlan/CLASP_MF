# %%
# Load libraries

# # Plotting utils 
import datetime
import glob
import os
import pickle
import time
import warnings
from datetime import date, timedelta
import Ngl
import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.util
import matplotlib as matplotlib
import matplotlib.animation as animation
import matplotlib.colors as colors
import matplotlib.dates as mdates
import matplotlib.patches as patches
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.ticker import FormatStrFormatter
import metpy.calc as mpc
import numpy as np
import pandas as pd
import scipy.stats as stats
import seaborn as sns
import xarray as xr
from matplotlib.dates import DateFormatter
from metpy.units import units
from metpy import interpolate
from metpy.calc import vertical_velocity
from mpl_toolkits.axes_grid1 import make_axes_locatable

warnings.filterwarnings('ignore')

# %%
# Grabbed from Brian M. to use time midpoints, not end periods
def cesm_correct_time(ds):
    """Given a Dataset, check for time_bnds,
       and use avg(time_bnds) to replace the time coordinate.
       Purpose is to center the timestamp on the averaging inverval.   
       NOTE: ds should have been loaded using `decode_times=False`
    """
    assert 'time_bnds' in ds
    assert 'time' in ds
    correct_time_values = ds['time_bnds'].mean(dim='nbnd')
    # copy any metadata:
    correct_time_values.attrs = ds['time'].attrs
    ds = ds.assign_coords({"time": correct_time_values})
    ds = xr.decode_cf(ds)  # decode to datetime objects
    return ds

# %% [markdown]
# **Minimal pre-processing**

# %%
# - - - - - - - - - - - - - - - 
# Pre-process data while reading in 
# - - - - - - - - - - - - - - - 

def preprocess_h0(ds):
       
    keepVars = ['SWCF','LWCF','TS','CLOUD','FSNS','FLNS','PS','QREFHT',
                'U10','CLDHGH','CLDLIQ','CONCLD','TMQ','P0','hyam','hybm','hyai','hybi',
                'PHIS','USTAR','QT','GCLDLWP',
                'THETAL','CDNUMC','CLDBOT','CLDLOW',
                'CLDMED','CLDTOP','CLDTOT','THLP2_CLUBB','CLOUDCOVER_CLUBB','CLOUDFRAC_CLUBB',
                'RCM_CLUBB','RTP2_CLUBB','RTPTHLP_CLUBB','RVMTEND_CLUBB','STEND_CLUBB','UP2_CLUBB','UPWP_CLUBB',
                'VP2_CLUBB','T','Q','OMEGA','PBLH','U','V','WP2_CLUBB','WP3_CLUBB','WPRCP_CLUBB',
                'WPRTP_CLUBB',
                'WPTHLP_CLUBB','WPTHVP_CLUBB','Z3','PRECT','PRECC',
                'TGCLDCWP','TGCLDLWP','GCLDLWP',
                'LHFLX','SHFLX','TREFHT','RHREFHT']
        
    ds         = cesm_correct_time(ds)
    ds['time'] = ds.indexes['time'].to_datetimeindex() 
        
    ## Select the second simulated day for analysis 
    # iTimeStart_day2  = np.where( (ds.time.values >= (ds.time.values[0] + np.timedelta64(1,'D'))) & 
    #                              (ds.time.values < (ds.time.values[0] + np.timedelta64(2,'D'))))[0]
    dsSel      = ds.isel(time=np.sort((ds.time.values >= (ds.time.values[0] + np.timedelta64(1,'D'))) & 
                                      (ds.time.values < (ds.time.values[0] + np.timedelta64(2,'D')))))[keepVars]
    
    # Compute local time 
    localTimes = dsSel['time'].values - np.timedelta64(5,'h')
    dsSel      = dsSel.assign_coords({"time": localTimes})
    
    return dsSel

def preprocess_h1(ds):
    
    keepVars = [
                'wpthlp','wprtp','rtp2',
                'thlm','rtm','wm_zm','rtm_zm','thlm_zm',
                ]
        
    ds         = cesm_correct_time(ds)
    ds['time'] = ds.indexes['time'].to_datetimeindex() 
        
    ## Select the second simulated day for analysis 
    dsSel      = ds.isel(time=np.sort((ds.time.values >= (ds.time.values[0] + np.timedelta64(1,'D'))) & 
                                      (ds.time.values < (ds.time.values[0] + np.timedelta64(2,'D')))))[keepVars]

    
    # Compute local time 
    localTimes = dsSel['time'].values - np.timedelta64(5,'h')
    dsSel      = dsSel.assign_coords({"time": localTimes})
        
    return dsSel


def preprocess_h2(ds):
    
    varSels = np.asarray([
                      'edmf_upa','edmf_upw','edmf_upqt','edmf_upthl','edmf_cloudfrac','edmf_dnw',
                      'edmf_precc','edmf_uplh',
                      'edmf_ent','edmf_upent','edmf_updet','edmf_upbuoy',

                       ])

    ds         = cesm_correct_time(ds)
    ds['time'] = ds.indexes['time'].to_datetimeindex() 
        
    ## Select the second simulated day for analysis 
    dsSel      = ds[varSels].isel(time=np.sort((ds.time.values >= (ds.time.values[0] + np.timedelta64(1,'D'))) & 
                                               (ds.time.values <= (ds.time.values[0] + np.timedelta64(2,'D')))))
    
    # Compute local time 
    localTimes = dsSel['time'].values - np.timedelta64(5,'h')
    dsSel      = dsSel.assign_coords({"time": localTimes})

    ## Replacing 'missing' updraft values with NaN 
    dsSel = dsSel.where(dsSel['edmf_upthl'] != 0.0).load()

    return dsSel


def preprocess_h2_2d(ds):
    
    varSels = np.asarray([
                      'edmf_cloudfrac','edmf_qtflxup','edmf_thlflxup','edmf_precc',
                      'edmf_S_ATHLTHL','edmf_S_AQTQT','edmf_S_AWW', 'edmf_L0',
                       ])

    ds         = cesm_correct_time(ds)
    ds['time'] = ds.indexes['time'].to_datetimeindex() 
        
    ## Select the second simulated day for analysis 
    dsSel      = ds[varSels].isel(time=np.sort((ds.time.values >= (ds.time.values[0] + np.timedelta64(1,'D'))) & 
                                 (ds.time.values < (ds.time.values[0] + np.timedelta64(2,'D')))))
    
    # Compute local time 
    localTimes = dsSel['time'].values - np.timedelta64(5,'h')
    dsSel      = dsSel.assign_coords({"time": localTimes}).load()    
    return dsSel

def preprocess_h3(ds):

    ds         = cesm_correct_time(ds)
    ds['time'] = ds.indexes['time'].to_datetimeindex() 
        
    ## Select the second simulated day for analysis 
    dsSel      = ds.isel(time=np.sort((ds.time.values >= (ds.time.values[0] + np.timedelta64(1,'D'))) & 
                                 (ds.time.values < (ds.time.values[0] + np.timedelta64(2,'D')))))
    
    # Compute local time 
    localTimes = dsSel['time'].values - np.timedelta64(5,'h')
    dsSel      = dsSel.assign_coords({"time": localTimes}).load()
    
    ## Replacing 'missing' updraft values with NaN 
    dsSel   = dsSel.where(dsSel['thlu_macmic2'] != 0.0)
    
    return dsSel

def preprocessCLM_h0(ds):
    keepVars_CLM = ['SOILWATER_10CM','TSOI_10CM','RAIN','FSA','TG','TSA',
                    'QVEGT','QVEGE','QSOIL','H2OSOI','TSOI','SOILLIQ']

    ds['time'] = ds.indexes['time'].to_datetimeindex() 
        
    ## Select the second simulated day for analysis 
    dsSel      = ds.isel(time=np.sort((ds.time.values >= (ds.time.values[0] + np.timedelta64(1,'D'))) & 
                                 (ds.time.values < (ds.time.values[0] + np.timedelta64(2,'D')))))[keepVars_CLM]
    
    # Compute local time 
    localTimes = dsSel['time'].values - np.timedelta64(5,'h')
    dsSel      = dsSel.assign_coords({"time": localTimes})

    return dsSel

def preprocessCLM_h1(ds):
    
    ds['time'] = ds.indexes['time'].to_datetimeindex() 
        
    ## Select the second simulated day for analysis 
    dsSel      = ds.isel(time=np.sort((ds.time.values >= (ds.time.values[0] + np.timedelta64(1,'D'))) & 
                                 (ds.time.values < (ds.time.values[0] + np.timedelta64(2,'D')))))
    
    # Compute local time 
    localTimes = dsSel['time'].values - np.timedelta64(5,'h')
    dsSel      = dsSel.assign_coords({"time": localTimes})
        
    QFLX = dsSel.QSOIL+dsSel.QVEGE+dsSel.QVEGT
    dsSel['QFLX'] = (('time','pft'), QFLX.values)
    
    return dsSel

def preprocessCLM_h2(ds):
    ds['time'] = ds.indexes['time'].to_datetimeindex() 
        
    ## Select the second simulated day for analysis 
    dsSel      = ds.isel(time=np.sort((ds.time.values >= (ds.time.values[0] + np.timedelta64(1,'D'))) & 
                                 (ds.time.values < (ds.time.values[0] + np.timedelta64(2,'D')))))
    
    # Compute local time 
    localTimes = dsSel['time'].values - np.timedelta64(5,'h')
    dsSel      = dsSel.assign_coords({"time": localTimes})
        
    QFLX = dsSel.QSOIL+dsSel.QVEGE+dsSel.QVEGT
    dsSel['QFLX'] = (('time','landunit'), QFLX.values)
    
    return dsSel

# %% [markdown]
# ## Start up dask

# %%
import dask

from dask_jobqueue import PBSCluster

# For Casper
cluster = PBSCluster(
    queue="casper",
    walltime="01:00:00",
    project="P93300642",
    #memory="4GB",
    #resource_spec="select=1:ncpus=1:mem=4GB",
    memory="10GB",
    resource_spec="select=1:ncpus=1:mem=10GB",
    cores=1,
    processes=1,
)

# # scale as needed
# cluster.adapt(minimum_jobs=1, maximum_jobs=30)
# cluster

# # Scale up
# cluster.scale(8)
# cluster

# %%
from dask.distributed import Client

# Connect client to the remote dask workers
client = Client(cluster)
client
# Out:
# <Client: 'tcp://128.117.208.76:35697' processes=0 threads=0, memory=0 B>

# %%
cluster.scale(24)

# %%
client.wait_for_workers(24)

# %%
client.status
# Out:
# 'running'

# %%
# client.shutdown()

# %%
# !qstat -u $USER

# %% [markdown]
# ## Read in data, but don't do a ton of extra processing yet

# %%
# %%time
testDir     = '/glade/derecho/scratch/mdfowler/CLASP+MF_diffusionOff/'

case_names  = [
                'clubbMF_L0eq250_diffOff',
                'claspMF_L0eq250_diffOff',
              ]

caseStart = 'FSCAM.T42_T42.arm97.CLASP_CLUBBMF_'

caseStrings = [
    'usePatchDataTRUE_25each_L0eq250_nup25_newHETterm_simplExtraPlume_diffOff_allJJA.',
    'usePatchDataTRUE_25each_L0eq250_nup25_newHETterm_simplExtraPlume_diffOff_allJJA.'
]

nens=25

for iCase in range(len(case_names)):
    print('*** Starting on case %s ***' % (case_names[iCase]))

    ## Get list of files 
    listFiles_h0 = np.sort(glob.glob(testDir+caseStart+caseStrings[iCase]+'*cam.h0.2016*'))
    listFiles_h1 = np.sort(glob.glob(testDir+caseStart+caseStrings[iCase]+'*cam.h1.2016*'))
    listFiles_h2 = np.sort(glob.glob(testDir+caseStart+caseStrings[iCase]+'*cam.h2.2016*'))
    listFiles_h3 = np.sort(glob.glob(testDir+caseStart+caseStrings[iCase]+'*cam.h3.2016*'))

    listFilesCLM_h2 = np.sort(glob.glob(testDir+caseStart+caseStrings[iCase]+'*clm2.h2.2016*'))
    listFilesCLM_h1 = np.sort(glob.glob(testDir+caseStart+caseStrings[iCase]+'*clm2.h1.2016*'))
    listFilesCLM_h0 = np.sort(glob.glob(testDir+caseStart+caseStrings[iCase]+'*clm2.h0.2016*'))        

    case_h0 = xr.open_mfdataset(listFiles_h0,  preprocess=preprocess_h0, concat_dim='time', 
                                combine='nested', decode_times=False, 
                                data_vars='minimal', parallel='True')
    print('h0 files loaded')
    case_h1 = xr.open_mfdataset(listFiles_h1,  preprocess=preprocess_h1, concat_dim='time', 
                                combine='nested', decode_times=False, 
                                data_vars='minimal', parallel='True')
    print('h1 files loaded')

    case_h2 = xr.open_mfdataset(listFiles_h2,  preprocess=preprocess_h2, concat_dim='time', 
                                combine='nested', decode_times=False, 
                                data_vars='minimal', parallel='True')
    print('h2 files loaded with mfdataset')
    case_h2_2d = xr.open_mfdataset(listFiles_h2,  preprocess=preprocess_h2_2d, concat_dim='time', 
                                combine='nested', decode_times=False, 
                                data_vars='minimal', parallel='True')
    print('h2 2D data loaded with mfdataset')
    
    case_h3 = xr.open_mfdataset(listFiles_h3,  preprocess=preprocess_h3, concat_dim='time', 
                                combine='nested', decode_times=False, 
                                data_vars='minimal', parallel='True')
    print('h3 files loaded with mfdataset')
        
    # Merge cases and load
    caseFull = xr.merge([case_h1, case_h0])
    del case_h0,case_h1
    
    caseH2   = xr.merge([case_h2, case_h2_2d])
    caseH2   = caseH2.assign_coords({"nens": np.arange(nens)})
    del case_h2,case_h2_2d

    if iCase==0:
        ncyc = len(case_h3.ncyc.values)
    
    caseH3   = case_h3.assign_coords({"nens": np.arange(nens)})
    caseH3   = caseH3.assign_coords({"ncyc": np.arange(ncyc)})
    del case_h3    
    # del case_h0,case_h1,case_h2,case_h2_2d,case_h3

    print('DS merged and loaded')

    ## Label with case info 
    caseFull_allDays   = caseFull.squeeze().assign_coords({"case":  case_names[iCase]})
    caseH2_allDays     = caseH2.squeeze().assign_coords({"case":  case_names[iCase]})
    caseH3_allDays     = caseH3.squeeze().assign_coords({"case":  case_names[iCase]})


    ## Read in CLM datasets too
    # - - - - - - - - - - - - - - - - - - - - 
    # caseCLM_h0 = xr.open_mfdataset(listFilesCLM_h0,  preprocess=preprocessCLM_h0, concat_dim='time', 
    #                             combine='nested', decode_times=True, 
    #                             data_vars='minimal', parallel='True')
    # print('CLM_h0 files loaded with mfdataset')

    caseCLM_h1 = xr.open_mfdataset(listFilesCLM_h1,  preprocess=preprocessCLM_h1, concat_dim='time', 
                                combine='nested', decode_times=True, 
                                data_vars='minimal', parallel='True')
    print('CLM_h1 files loaded with mfdataset')
    
    caseCLM_h2 = xr.open_mfdataset(listFilesCLM_h2,  preprocess=preprocessCLM_h2, concat_dim='time', 
                                combine='nested', decode_times=True, 
                                data_vars='minimal', parallel='True')
    print('CLM_h2 files loaded with mfdataset')

    caseCLMh1_allDays = caseCLM_h1.assign_coords({"case":  case_names[iCase]})
    caseCLMh2_allDays = caseCLM_h2.assign_coords({"case":  case_names[iCase]})

    del caseCLM_h1,caseCLM_h2

    ## Combine everthing into one larger array 
    # - - - - - - - - - - - - - - - - - - - - 
    if iCase==0:
        scamDS    = caseFull_allDays
        del caseFull_allDays
        scamDS_h2 = caseH2_allDays
        del caseH2_allDays
        scamDS_h3 = caseH3_allDays
        del caseH3_allDays
        
        clmDS_h1 = caseCLMh1_allDays
        del caseCLMh1_allDays
        clmDS_h2 = caseCLMh2_allDays
        del caseCLMh2_allDays
    else: 
        scamDS    = xr.concat([scamDS, caseFull_allDays], "case") 
        del caseFull_allDays
        scamDS_h2 = xr.concat([scamDS_h2, caseH2_allDays], "case") 
        del caseH2_allDays
        scamDS_h3 = xr.concat([scamDS_h3, caseH3_allDays], "case") 
        del caseH3_allDays
        
        clmDS_h1 = xr.concat([clmDS_h1, caseCLMh1_allDays], "case") 
        del caseCLMh1_allDays
        clmDS_h2 = xr.concat([clmDS_h2, caseCLMh2_allDays], "case") 
        del caseCLMh2_allDays
# Out:
# *** Starting on case clubbMF_L0eq250_diffOff ***
# h0 files loaded
# h1 files loaded
# h2 files loaded with mfdataset
# h2 2D data loaded with mfdataset
# 2024-02-26 12:37:31,959 - distributed.scheduler - ERROR - Couldn't gather keys: {('where-1dbad44dce53b6c24d7c357e40b2d2af', 0, 0, 0, 0, 0, 0): 'memory', ('where-e77d1fda21f2ba576b9297fd5e31fbe8', 0, 0, 0, 0, 0, 0): 'memory', ('where-20713d2d5bfd4f44fbc09fa2a89546b1', 0, 0, 0, 0, 0, 0, 0): 'memory', ('where-98f45375178f9d986c74630a4554d803', 0, 0, 0, 0, 0, 0): 'memory', ('where-9a25aaac326e6e75573a7f027edff437', 0, 0, 0, 0, 0, 0): 'memory', ('where-a20f06be539a8f0d7e96287b2aa34cf0', 0, 0, 0, 0, 0, 0): 'memory', ('where-29e53ca7f62e909f4c0352843e8cdb6a', 0, 0, 0, 0, 0, 0, 0): 'memory', ('where-4e2ba32e1de1b5e7d0e49df8f0cedb3d', 0, 0, 0, 0, 0, 0): 'memory'}
# 2024-02-26 12:37:31,968 - distributed.scheduler - ERROR - Couldn't gather keys: {('where-97655930404e862605893a66504f2a7a', 0, 0, 0, 0, 0, 0): 'waiting', ('where-83dd87140077a93b02dfbf732afabd19', 0, 0, 0, 0, 0, 0): 'waiting'}
# 2024-02-26 12:37:31,971 - distributed.scheduler - ERROR - Couldn't gather keys: {('where-8ae440d57738ade7c34a4e82af9f6d36', 0, 0, 0, 0, 0, 0): 'waiting', ('where-c90da88e90ef78fbbad4839e33906cac', 0, 0, 0, 0, 0, 0): 'waiting', ('where-b5c667227e60db47b2f639e0af64c74c', 0, 0, 0, 0, 0, 0): 'waiting', ('where-7b328513c07461e1cdda766ec1668444', 0, 0, 0, 0, 0, 0): 'waiting', ('where-dc521aaf7bb425dc9f7fefbfa2bdacd4', 0, 0, 0, 0, 0, 0): 'waiting', ('where-ded5197ae47636dc7d576a6e7106987f', 0, 0, 0, 0, 0, 0): 'waiting', ('where-a3664b7e4f8d1036aa96862bb940eba2', 0, 0, 0, 0, 0, 0): 'waiting', ('where-233a713d24eb19aad9cd406293c9040c', 0, 0, 0, 0, 0, 0): 'waiting', ('where-9fbae27c22f44b1fb56e7728a8ec5efa', 0, 0, 0, 0, 0, 0): 'waiting', ('where-75af9a35e28984f35565d2784fdf62ac', 0, 0, 0, 0, 0, 0): 'waiting', ('where-660c145fa4f0db31819a1392d6d4d09a', 0, 0, 0, 0, 0, 0): 'waiting', ('where-a12606a89b8b1af16991f55e665e1747', 0, 0, 0, 0, 0, 0): 'waiting'}
# 2024-02-26 12:37:31,972 - distributed.scheduler - ERROR - Couldn't gather keys: {('where-95766dac66ba0d4c3f0ad47bb20bac20', 0, 0, 0, 0, 0, 0, 0): 'waiting', ('where-2196a303d333472f758953a2c330b5ea', 0, 0, 0, 0, 0, 0): 'waiting', ('where-7661119b3ac47a0b87483963b952bfae', 0, 0, 0, 0, 0, 0): 'waiting'}
# 2024-02-26 12:37:31,974 - distributed.scheduler - ERROR - Couldn't gather keys: {('where-ac1e17d3e4c81d367ed1482aeee37961', 0, 0, 0, 0, 0, 0, 0): 'waiting', ('where-d6a8b474891e97bfad5556200b8f5e55', 0, 0, 0, 0, 0, 0): 'waiting'}
# 2024-02-26 12:37:31,975 - distributed.scheduler - ERROR - Couldn't gather keys: {('where-3327d061ea077e0175008057a3bd8b69', 0, 0, 0, 0, 0, 0): 'waiting', ('where-58635f4efa433172bd1c604adc73e452', 0, 0, 0, 0, 0, 0): 'waiting', ('where-ce2c12596cbc49b896d428b9060467f6', 0, 0, 0, 0, 0, 0): 'waiting', ('where-23d7ce6def0fe4a5e015e0840be8f5e9', 0, 0, 0, 0, 0, 0): 'waiting'}
# 2024-02-26 12:37:31,976 - distributed.scheduler - ERROR - Couldn't gather keys: {('where-3d4dae0cf1c6dd24299a4357f145bd97', 0, 0, 0, 0, 0, 0): 'waiting', ('where-3d3a778a46b7747aab603fa46d051440', 0, 0, 0, 0, 0, 0): 'waiting'}
# 2024-02-26 12:37:31,977 - distributed.scheduler - ERROR - Couldn't gather keys: {('where-962ed8a3d4e37873047ea1321a5aff56', 0, 0, 0, 0, 0, 0): 'waiting', ('where-f2ee4fa5136ad78a5baa042f6c941350', 0, 0, 0, 0, 0, 0): 'waiting', ('where-5341d40e6cbb3036b435bbb3ff586617', 0, 0, 0, 0, 0, 0): 'waiting'}
# 2024-02-26 12:37:31,979 - distributed.scheduler - ERROR - Couldn't gather keys: {('where-cc949e322dc659fc9c116cbf96119bc6', 0, 0, 0, 0, 0, 0): 'waiting', ('where-9d0fe02e036d165ea100ed45d8fc641e', 0, 0, 0, 0, 0, 0): 'waiting', ('where-16e314af5acadf9f12430fd70d9a9c58', 0, 0, 0, 0, 0, 0, 0): 'waiting', ('where-af7b8ef4d6ca3d0e43f2cc5cc2a731a7', 0, 0, 0, 0, 0, 0): 'waiting', ('where-097b6cb233b6d08417276af299e355bc', 0, 0, 0, 0, 0, 0): 'waiting', ('where-2135d946950ea62ad3018b2805c3123f', 0, 0, 0, 0, 0, 0): 'waiting'}
# 2024-02-26 12:37:31,980 - distributed.scheduler - ERROR - Couldn't gather keys: {('where-24cc8f10656fd97257e37e56bfd1f4a9', 0, 0, 0, 0, 0, 0): 'waiting', ('where-1994b042220f9478dcaa28d5fa3b4ff9', 0, 0, 0, 0, 0, 0): 'waiting', ('where-3c233c0456e6c72e5db796858039ff80', 0, 0, 0, 0, 0, 0): 'waiting', ('where-10707817d024376a6be1285474d6e8f1', 0, 0, 0, 0, 0, 0): 'waiting', ('where-7b6a26773e23ab1cfd03d1f74a1251fb', 0, 0, 0, 0, 0, 0): 'waiting', ('where-fc6e0c07b665df4e6b51384037947712', 0, 0, 0, 0, 0, 0): 'waiting', ('where-c0693e2b4e2fcbcdcac3ef26d284127a', 0, 0, 0, 0, 0, 0): 'waiting'}
# 2024-02-26 12:37:31,990 - distributed.scheduler - ERROR - Couldn't gather keys: {('where-6ec0fe8e73fe8a6605592a61d37ca558', 0, 0, 0, 0, 0, 0): 'waiting'}
# 2024-02-26 12:37:31,991 - distributed.scheduler - ERROR - Couldn't gather keys: {('where-bcd22bd82bc46f518a236d3b2a169d64', 0, 0, 0, 0, 0, 0): 'waiting', ('where-c9c2c964e8373a9a8b5f888fa3251605', 0, 0, 0, 0, 0, 0): 'waiting'}
# 2024-02-26 12:37:31,992 - distributed.scheduler - ERROR - Couldn't gather keys: {('where-cc08bed70b9ce881e362f9355284288b', 0, 0, 0, 0, 0, 0): 'waiting', ('where-60134a13a3b0f24c3c0be3a082e3c963', 0, 0, 0, 0, 0, 0, 0): 'waiting'}
# 2024-02-26 12:37:31,995 - distributed.scheduler - ERROR - Couldn't gather keys: {('where-ab093a7028b09ef2cb174afd2935a73f', 0, 0, 0, 0, 0, 0): 'waiting', ('where-419330d59704052d23c42b60e6e4ae80', 0, 0, 0, 0, 0, 0): 'waiting', ('where-36b79cb6cdfacb4df29619a08b4ad901', 0, 0, 0, 0, 0, 0): 'waiting', ('where-295acd6d530be09ad933fa9e8940d295', 0, 0, 0, 0, 0, 0): 'waiting'}
# 2024-02-26 12:37:32,009 - distributed.scheduler - ERROR - Couldn't gather keys: {('where-bbdd4dfe51838720263aaa9003673d32', 0, 0, 0, 0, 0, 0): 'waiting', ('where-68cf13c373812eb3136270e0f03f3626', 0, 0, 0, 0, 0, 0): 'waiting', ('where-eac5decd4902dddaf43aba877f7b1d49', 0, 0, 0, 0, 0, 0): 'waiting', ('where-96da29db3612cb18b8ff076962580859', 0, 0, 0, 0, 0, 0, 0): 'waiting', ('where-3ba4b31422948710999d7be0457db701', 0, 0, 0, 0, 0, 0): 'waiting'}
# 2024-02-26 12:37:32,010 - distributed.scheduler - ERROR - Couldn't gather keys: {('where-88f686c1dd136c77b8187d33d1bf69d4', 0, 0, 0, 0, 0, 0): 'waiting', ('where-981095824f4b2e76573b075240062f6a', 0, 0, 0, 0, 0, 0): 'waiting', ('where-ac326922b56293d410ce06bd033f66b8', 0, 0, 0, 0, 0, 0): 'waiting', ('where-ba472bb55010afffadf28a6220bd91ac', 0, 0, 0, 0, 0, 0): 'waiting', ('where-8e15394637da71953e8cad617edf9711', 0, 0, 0, 0, 0, 0): 'waiting', ('where-42a94dc36f943f1cd62842ba21b09f53', 0, 0, 0, 0, 0, 0): 'waiting', ('where-5261d21204510f7a23e526c927ab4820', 0, 0, 0, 0, 0, 0, 0): 'waiting', ('where-4f92b3d5f2e896745151c9dbe0999f24', 0, 0, 0, 0, 0, 0): 'waiting', ('where-2111c7704b9edc95adb8ba1257a202e0', 0, 0, 0, 0, 0, 0): 'waiting', ('where-61493c2e724c606679c294077e23d9b1', 0, 0, 0, 0, 0, 0, 0): 'waiting', ('where-413f1ed455f67f413747d82ec78afa4e', 0, 0, 0, 0, 0, 0): 'waiting', ('where-8dd7d2c61e0d952a790f6bf2cc293c89', 0, 0, 0, 0, 0, 0): 'waiting', ('where-ef5dbb455f7d927d791471d80e84b192', 0, 0, 0, 0, 0, 0, 0): 'waiting'}
# 2024-02-26 12:37:32,092 - distributed.scheduler - ERROR - Couldn't gather keys: {('where-622c7b1e5c548d3a63861d1eb30023f4', 0, 0, 0, 0, 0, 0): 'waiting', ('where-d6de48929c25bd8e93e09d3fa628b067', 0, 0, 0, 0, 0, 0): 'waiting', ('where-697455a786502833e9317732ccbb03f1', 0, 0, 0, 0, 0, 0): 'waiting', ('where-a37bfd4183d401bc955049989991a99f', 0, 0, 0, 0, 0, 0): 'waiting', ('where-afed9f98689f36cfe40e2a28e8cc2cef', 0, 0, 0, 0, 0, 0, 0): 'waiting', ('where-19cf5462b9053478bcea60c1f158082e', 0, 0, 0, 0, 0, 0): 'waiting', ('where-cddbb2665dd0bbb2a3bda963aadec703', 0, 0, 0, 0, 0, 0): 'waiting', ('where-696a8770ee8ecef8b79febbe35dfcbf6', 0, 0, 0, 0, 0, 0): 'waiting', ('where-dcf3aa6276215ee2dfc39a54bc26a8b4', 0, 0, 0, 0, 0, 0): 'waiting', ('where-4d809ef9459dd60ada117d85e7038742', 0, 0, 0, 0, 0, 0): 'waiting', ('where-8f2b5345655c7477118803a1e7929408', 0, 0, 0, 0, 0, 0): 'waiting', ('where-e2cae40b64c308f6aae85e3d641732e5', 0, 0, 0, 0, 0, 0): 'waiting'}
# 2024-02-26 12:37:32,102 - distributed.scheduler - ERROR - Couldn't gather keys: {('where-2adc77d5676f4d81dfbef6b7128fc49b', 0, 0, 0, 0, 0, 0): 'waiting', ('where-dea6fede9a0f90a7d1c458fd0cfd5ed1', 0, 0, 0, 0, 0, 0, 0): 'waiting', ('where-544216a88c63f17af82b86534ec609dd', 0, 0, 0, 0, 0, 0): 'waiting', ('where-80117fc8798e208175d53154bbecd79d', 0, 0, 0, 0, 0, 0): 'waiting', ('where-bff85f521f1d4d7afa1aa91c5710bda5', 0, 0, 0, 0, 0, 0): 'waiting', ('where-0739bb83d7bb5cead4803065c250166b', 0, 0, 0, 0, 0, 0): 'waiting', ('where-9e5d87493508b2d9d0b87f10f53d51d5', 0, 0, 0, 0, 0, 0): 'waiting', ('where-421fbe279e7f0e2abc6375c8bb09ea69', 0, 0, 0, 0, 0, 0): 'waiting'}

# %% [markdown]
# **Okay, now how about some *more efficient* processing?**

# %% [markdown]
# Test the old way first:

# %%
# - - - - - - - - - - - - - - - 
# Additional processing after files are read in 
# - - - - - - - - - - - - - - - 

def process_camData(DS):
    
    ## Interpolate to standard levels 
    # - - - - - - - - - - - - - - - - - - - - - - - -
    print('Beginning interpolation...') 
    
    # Decide on levels to interpoalte to and add to larger arrays
    pnew64 = np.arange(200.0,980.0,10.0) 
    
    DS = DS.assign_coords({"levInterp": pnew64})

    varSels = np.asarray(['THLP2_CLUBB','RTP2_CLUBB','RTPTHLP_CLUBB','WPRTP_CLUBB','WPTHLP_CLUBB','WP3_CLUBB','WP2_CLUBB','UP2_CLUBB',
                          'VP2_CLUBB','Z3','U','V','T','Q','OMEGA','RVMTEND_CLUBB','STEND_CLUBB','CLDLIQ','CLOUD','CLOUDFRAC_CLUBB',
                          'UPWP_CLUBB','THETAL',
                          'CONCLD','QT','GCLDLWP',
                          'wpthlp','wprtp','rtp2',
                          'thlm','rtm','wm_zm','rtm_zm','thlm_zm',
                          ])

    for iVar in range(len(varSels)): 

        DS[varSels[iVar]] = DS[varSels[iVar]].expand_dims({'lat': 1}, axis=-1)
        DS[varSels[iVar]] = DS[varSels[iVar]].expand_dims({'lon': 1}, axis=-1)
        
        # Interpolate variables and add to larger arrays 
        interpVar_real = interpolateToPressure_v2(DS, varSels[iVar], pnew64)

        if len(np.shape(interpVar_real))==2: 
            DS[varSels[iVar]+'_interp']  = (('time','levInterp'), interpVar_real)
        elif len(np.shape(interpVar_real))==3: 
            DS[varSels[iVar]+'_interp']  = (('time','nens','levInterp'), interpVar_real)

        
    return DS


def process_camData_h2(DS, DSctrl):
    ## Interpolate to standard levels 
    # - - - - - - - - - - - - - - - - - - - - - - - -
    print('Beginning interpolation...') 
    
    # Decide on levels to interpoalte to and add to larger arrays
    pnew64 = np.arange(200.0,980.0,10.0) 
    
    DS = DS.assign_coords({"levInterp": pnew64})
    varSels = np.asarray([
                          'edmf_upa','edmf_upw','edmf_upqt','edmf_upthl',
                          'edmf_cloudfrac','edmf_dnw','edmf_precc',
                          'edmf_qtflxup','edmf_thlflxup',
                          'edmf_S_ATHLTHL','edmf_S_AQTQT','edmf_S_AWW',
                           'edmf_ent','edmf_upent','edmf_updet','edmf_upbuoy',

                           ])

    for iVar in range(len(varSels)): 
        DS[varSels[iVar]] = DS[varSels[iVar]].expand_dims({'lat': 1}, axis=-1)
        DS[varSels[iVar]] = DS[varSels[iVar]].expand_dims({'lon': 1}, axis=-1)

        # Interpolate variables and add to larger arrays 
        interpVar_real = interpolateToPressure_v2_h2(DS, DSctrl, varSels[iVar], pnew64)

        if len(np.shape(interpVar_real))==2: 
            DS[varSels[iVar]+'_interp']  = (('time','levInterp'), interpVar_real)
        elif len(np.shape(interpVar_real))==3: 
            DS[varSels[iVar]+'_interp']  = (('time','nens','levInterp'), interpVar_real)

    return DS

def process_camData_h3(DS, DSctrl):
    
    ## Interpolate to standard levels 
    # - - - - - - - - - - - - - - - - - - - - - - - -
    print('Beginning interpolation...') 
    
    # Decide on levels to interpoalte to and add to larger arrays
    pnew64 = np.arange(200.0,980.0,10.0) 
    
    DS = DS.assign_coords({"levInterp": pnew64})
    
    varSels = np.asarray(['up_macmicAvg', 'dn_macmicAvg','upa_macmicAvg','dna_macmicAvg',
               'thlu_macmicAvg','qtu_macmicAvg','thld_macmicAvg','qtd_macmicAvg' ])
    
    for iVar in range(len(varSels)): 
        DS[varSels[iVar]] = DS[varSels[iVar]].expand_dims({'lat': 1}, axis=-1)
        DS[varSels[iVar]] = DS[varSels[iVar]].expand_dims({'lon': 1}, axis=-1)

        # Interpolate variables and add to larger arrays 
        interpVar_real = interpolateToPressure_v2_h3(DS, DSctrl, varSels[iVar], pnew64)

        if len(np.shape(interpVar_real))==2: 
            DS[varSels[iVar]+'_interp']  = (('time','levInterp'), interpVar_real)
        elif len(np.shape(interpVar_real))==3: 
            DS[varSels[iVar]+'_interp']  = (('time','nens','levInterp'), interpVar_real)
        elif len(np.shape(interpVar_real))==4: 
            DS[varSels[iVar]+'_interp']  = (('time','ncyc','nens','levInterp'), interpVar_real)
        
    return DS

# %%
# - - - - - - - - - - - - - - - 
# Pressure interpolation 
# - - - - - - - - - - - - - - - 

def interpolateToPressure_v2(DS, varName, pressGoals):
    p0mb = DS.P0.values/100        # mb

    # Pull out hya/hyb profiles 
    hyam = np.squeeze(DS.hyam.values)[:]
    hybm = np.squeeze(DS.hybm.values)[:]
    hyai = np.squeeze(DS.hyai.values)[:]
    hybi = np.squeeze(DS.hybi.values)[:]

    # Surface pressure with time dimension
    PS   = DS.PS.values              # Pa

    # Converting variables: 
    if np.shape(DS[varName].values)[1]==len(DS.ilev.values):
        varInterp = Ngl.vinth2p(DS[varName].values,hyai,hybi,pressGoals,PS,1,p0mb,1,True)
    elif np.shape(DS[varName].values)[1]==len(DS.lev.values):
        varInterp = Ngl.vinth2p(DS[varName].values,hyam,hybm,pressGoals,PS,1,p0mb,1,True)
    ## Handle data that's by-plume for EDMF output
    elif np.shape(DS[varName].values)[1]==len(DS.nens.values):
        varInterp = np.full([len(DS.time.values), len(DS.nens.values) ,
                             len(pressGoals)], np.nan)
        
        for iEns in range(len(DS.nens.values)):
            varInterp[:,iEns,:] = np.squeeze(Ngl.vinth2p(DS[varName].values[:,iEns,:],hyai,hybi,pressGoals,PS,1,p0mb,1,True))

    saveOut = varInterp
    
    return saveOut

def interpolateToPressure_v2_h2(DS, DSctrl, varName, pressGoals):
    p0mb = DSctrl.P0.values/100        # mb

    # Pull out hya/hyb profiles 
    hyam = np.squeeze(DSctrl.hyam.values)[:]
    hybm = np.squeeze(DSctrl.hybm.values)[:]
    hyai = np.squeeze(DSctrl.hyai.values)[:]
    hybi = np.squeeze(DSctrl.hybi.values)[:]

    # Surface pressure with time dimension
    PS   = DSctrl.PS.values              # Pa 

    # Converting variables: 
    if np.shape(DS[varName].values)[1]==len(DS.ilev.values):
        varInterp = Ngl.vinth2p(DS[varName].values,hyai,hybi,pressGoals,PS,1,p0mb,1,True)
    elif np.shape(DS[varName].values)[1]==len(DS.lev.values):
        varInterp = Ngl.vinth2p(DS[varName].values,hyam,hybm,pressGoals,PS,1,p0mb,1,True)
    ## Handle data that's by-plume for EDMF output
    elif np.shape(DS[varName].values)[1]==len(DS.nens.values):
        varInterp = np.full([len(DS.time.values), len(DS.nens.values) ,
                             len(pressGoals)], np.nan)
        
        for iEns in range(len(DS.nens.values)):
            varInterp[:,iEns,:] = np.squeeze(Ngl.vinth2p(DS[varName].values[:,iEns,:],hyai,hybi,pressGoals,PS,1,p0mb,1,True))

    saveOut = varInterp
    
    return saveOut


def interpolateToPressure_v2_h3(DS, DSctrl, varName, pressGoals):
    p0mb = DSctrl.P0.values/100        # mb

    # Pull out hya/hyb profiles 
    hyam = np.squeeze(DSctrl.hyam.values)[:]
    hybm = np.squeeze(DSctrl.hybm.values)[:]
    hyai = np.squeeze(DSctrl.hyai.values)[:]
    hybi = np.squeeze(DSctrl.hybi.values)[:]

    # Surface pressure with time dimension
    PS   = DSctrl.PS.values              # Pa 

    # Converting variables: 
    if np.shape(DS[varName].values)[1]==len(DS.ilev.values):
        varInterp = Ngl.vinth2p(DS[varName].values,hyai,hybi,pressGoals,PS,1,p0mb,1,True)
    elif np.shape(DS[varName].values)[1]==len(DS.lev.values):
        varInterp = Ngl.vinth2p(DS[varName].values,hyam,hybm,pressGoals,PS,1,p0mb,1,True)
    ## Handle data that's by-plume for EDMF output
    elif np.shape(DS[varName].values)[1]==len(DS.nens.values):
        varInterp = np.full([len(DS.time.values), len(DS.nens.values),
                             len(pressGoals)], np.nan)
        
        for iEns in range(len(DS.nens.values)):
            varInterp[:,iEns,:] = np.squeeze(Ngl.vinth2p(DS[varName].values[:,iEns,:],hyai,hybi,pressGoals,PS,1,p0mb,1,True))
 
    ## Handle data that's by-plume *and* by subcycle for EDMF output
    elif np.shape(DS[varName].values)[2]==len(DS.nens.values):
        varInterp = np.full([len(DS.time.values), len(DS.ncyc.values), len(DS.nens.values) ,
                             len(pressGoals)], np.nan)
        
        for iEns in range(len(DS.nens.values)):
            for iCyc in range(len(DS.ncyc.values)):
                varInterp[:,iCyc,iEns,:] = np.squeeze(Ngl.vinth2p(DS[varName].values[:,iCyc,iEns,:],hyai,hybi,pressGoals,PS,1,p0mb,1,True))

            
    saveOut = np.squeeze(varInterp)
    
    return saveOut

# %%
def combineMacmic_beforeInterp(ds_h3):
    var1    = ['up_macmic1', 'dn_macmic1','upa_macmic1','dna_macmic1',
           'thlu_macmic1','qtu_macmic1','thld_macmic1','qtd_macmic1']

    var2    = ['up_macmic2', 'dn_macmic2','upa_macmic2','dna_macmic2',
               'thlu_macmic2','qtu_macmic2','thld_macmic2','qtd_macmic2']

    varSave = ['up_macmicAvg', 'dn_macmicAvg','upa_macmicAvg','dna_macmicAvg',
               'thlu_macmicAvg','qtu_macmicAvg','thld_macmicAvg','qtd_macmicAvg']

    for iVar in range(len(var1)):
#         print('Computing %s' % (varSave[iVar]))

        varCyc1 = ds_h3[var1[iVar]]
        varCyc2 = ds_h3[var2[iVar]]
        
        ## ADDED 8/8/23: Need to filter out areas that are zero...
        condition1 = ds_h3['upa_macmic1']>0
        subset_ds1 = varCyc1.where(condition1)

        condition2 = ds_h3['upa_macmic2']>0
        subset_ds2 = varCyc2.where(condition2)

        ## This seems to work... 
        # s = np.stack((varCyc1, varCyc2))
        s = np.stack((subset_ds1, subset_ds2))
        # C = np.nansum(s, axis=0)
        C = np.nanmean(s, axis=0)
        C[np.all(np.isnan(s), axis=0)] = np.nan

        # ds_h3[varSave[iVar]]  = (('time','nens','ilev','lat','lon'), C)
        ds_h3[varSave[iVar]]  = (('time','nens','ilev'), np.squeeze(C))
        
        # ds_h3[varSave[iVar]] = ds_h3[varSave[iVar]].expand_dims({'lat': 1}, axis=-1)
        # ds_h3[varSave[iVar]] = ds_h3[varSave[iVar]].expand_dims({'lon': 1}, axis=-1)
        
        if var1[iVar]!='upa_macmic1': 
            ds_h3 = ds_h3.drop_vars(var1[iVar])
        if var2[iVar]!='upa_macmic2':
            ds_h3 = ds_h3.drop_vars(var2[iVar])
    
    return ds_h3

# %%
scamDS['PS'] = scamDS['PS'].expand_dims({'lat': 1}, axis=-1)
scamDS['PS'] = scamDS['PS'].expand_dims({'lon': 1}, axis=-1)

# %% [markdown]
# **Start up dask server here**

# %%
# %%time 
scamDS.load() 
print('Hey look! scamDS all loaded in.')
# Out:
# Hey look! scamDS all loaded in.
# CPU times: user 28.1 s, sys: 2.5 s, total: 30.6 s
# Wall time: 39.2 s

# %%
# %%time
scamDS_h2.load()
# scamDS_h2.compute()
# scamDS_h2 = client.persist(scamDS_h2)

print('scamDS_h2 made it too! All warshed up and clean')
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-897869' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898264' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898175' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898523' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898194' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898368' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898238' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898152' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898366' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898351' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898293' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898181' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898537' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898504' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898381' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898499' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898137' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898207' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898448' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898258' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898251' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898560' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898227' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898302' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898457' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898162' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898140' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898154' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898479' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898350' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898531' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898497' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898298' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898552' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898318' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898521' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898116' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898449' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898121' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898453' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898343' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898559' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898542' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898322' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898397' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898527' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898221' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898190' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898219' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898133' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898126' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898147' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898187' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898564' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898440' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898387' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898408' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898405' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898382' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:1
#
# File /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/xarray/core/dataset.py:853, in Dataset.load(self, **kwargs)
#     850 chunkmanager = get_chunked_array_type(*lazy_data.values())
#     852 # evaluate all the chunked arrays simultaneously
# --> 853 evaluated_data = chunkmanager.compute(*lazy_data.values(), **kwargs)
#     855 for k, data in zip(lazy_data, evaluated_data):
#     856     self.variables[k].data = data
#
# File /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/xarray/core/daskmanager.py:70, in DaskManager.compute(self, *data, **kwargs)
#      67 def compute(self, *data: DaskArray, **kwargs) -> tuple[np.ndarray, ...]:
#      68     from dask.array import compute
# ---> 70     return compute(*data, **kwargs)
#
# File /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/dask/base.py:665, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     662     postcomputes.append(x.__dask_postcompute__())
#     664 with shorten_traceback():
# --> 665     results = schedule(dsk, keys, **kwargs)
#     667 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/threading.py:629, in Event.wait(self, timeout)
#     627 signaled = self._flag
#     628 if not signaled:
# --> 629     signaled = self._cond.wait(timeout)
#     630 return signaled
#
# File /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/threading.py:331, in Condition.wait(self, timeout)
#     329 else:
#     330     if timeout > 0:
# --> 331         gotit = waiter.acquire(True, timeout)
#     332     else:
#     333         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# Task exception was never retrieved
# future: <Task finished name='Task-898216' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898452' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898467' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898469' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898578' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898199' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898472' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit

# %%
# %%time 

## Process data 
procDS_case0    = process_camData( scamDS.isel(case=0) )
procDS_case1    = process_camData( scamDS.isel(case=1) )
procDS = xr.concat([procDS_case0, procDS_case1], "case") 
print('Done with procDS')
#del scamDS

procDS_h2_case0 = process_camData_h2( scamDS_h2.isel(case=0) , procDS.isel(case=0)  )
procDS_h2_case1 = process_camData_h2( scamDS_h2.isel(case=1) , procDS.isel(case=1)  )
procDS_h2 = xr.concat([procDS_h2_case0, procDS_h2_case1], "case") 
## Drop excessive variables to save space
procDS_h2 = procDS_h2.drop_vars(['ntrk','ntrn','ntrm','gw','hyam','hybm',                                  
                             'P0','hyai','hybi','date','datesec','time_bnds','date_written',
                             'time_written','ndbase','nsbase','nbdate','nbsec','mdt','ndcur',
                             'nscur','co2vmr','ch4vmr','n2ovmr','f11vmr','f12vmr','sol_tsi','nsteph',
                              ## Also remove downdraft data (not active here)
                             'qtd_macmicAvg_interp','thld_macmicAvg_interp',
                              'qtd_macmicAvg','thld_macmicAvg','dna_macmicAvg',
                              'dn_macmicAvg','upa_macmic2','upa_macmic1','edmf_dnw_interp',
                              # 'dn_macmicAvg_interp', 'dna_macmicAvg_interp',  
                              ## Also drop macmicAvg if not interpolated 
                              'up_macmicAvg','upa_macmicAvg','thlu_macmicAvg','qtu_macmicAvg',
                              ## Riskier - but drop the things that are just the last time-step
                              # 'edmf_upa','edmf_upw','edmf_upqt','edmf_upthl',
                                ])
print('Done with procDS_h2')
#del scamDS_h2

procDS_h3_combine_case0 = combineMacmic_beforeInterp(scamDS_h3.isel(case=0))
procDS_h3_combine_case1 = combineMacmic_beforeInterp(scamDS_h3.isel(case=1))
procDS_h3_combine = xr.concat([procDS_h3_combine_case0, procDS_h3_combine_case1], "case")
procDS_h3_combine.load() 
print('We loaded h3!')
# del scamDS_h3
procDS_h3_case0 = process_camData_h3( procDS_h3_combine.isel(case=0), procDS.isel(case=0)  )
procDS_h3_case1 = process_camData_h3( procDS_h3_combine.isel(case=1), procDS.isel(case=1)  )
procDS_h3 = xr.concat([procDS_h3_case0, procDS_h3_case1], "case")
del procDS_h3_combine
print('Done with procDS_h3')

procDS_h2 = xr.merge([procDS_h2, procDS_h3])
del procDS_h3
        
## Combine all the cases into 
case_allDays      = procDS
h2_allDays        = procDS_h2
del procDS_h2, procDS
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-898160' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898547' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898458' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898455' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898481' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898315' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898285' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898168' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898372' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898540' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898484' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898424' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898573' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898287' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898482' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898388' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898507' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898581' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898384' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898354' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898463' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898525' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898515' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898514' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898500' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898409' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898241' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898125' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898280' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898432' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898420' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898290' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898149' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898444' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898415' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898269' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898437' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898567' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898224' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898213' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898183' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898281' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898144' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898325' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898374' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898466' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898489' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898442' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898337' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898475' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898393' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898271' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898167' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898464' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898461' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898485' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898517' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898310' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898363' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898338' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898174' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898201' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898478' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898511' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898528' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898210' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898252' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-899745' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-899704' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897823' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897922' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897792' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897996' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897832' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897751' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897710' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897825' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897837' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898038' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897818' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898027' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897940' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897987' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897707' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897888' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897991' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897908' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898041' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898009' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898082' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898067' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898106' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897938' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897899' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897944' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897755' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897715' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897964' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898005' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897843' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897799' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897771' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897882' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897848' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897856' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897958' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-898061' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
# ...
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-899452' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-899419' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-899468' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-899461' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-899210' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-896768' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897399' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897539' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897380' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897283' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897296' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897534' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897494' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897344' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897277' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897517' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897522' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897373' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897203' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897254' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897236' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897319' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897643' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897180' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897358' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897394' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897538' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897471' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897446' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897259' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897127' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897408' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897693' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897142' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897154' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit

# %%
client.status

# %%
client.shutdown()

# %%
DSctrl = procDS.isel(case=0)
DS = ds1
varName = 'up_macmicAvg'
pressGoals = np.arange(200.0,980.0,10.0) 



p0mb = DSctrl.P0.values/100        # mb

# Pull out hya/hyb profiles 
hyam = np.squeeze(DSctrl.hyam.values)[:]
hybm = np.squeeze(DSctrl.hybm.values)[:]
hyai = np.squeeze(DSctrl.hyai.values)[:]
hybi = np.squeeze(DSctrl.hybi.values)[:]

# Surface pressure with time dimension
PS   = DSctrl.PS.values              # Pa 

# Converting variables: 
if np.shape(DS[varName].values)[1]==len(DS.ilev.values):
    varInterp = Ngl.vinth2p(DS[varName].values,hyai,hybi,pressGoals,PS,1,p0mb,1,True)
elif np.shape(DS[varName].values)[1]==len(DS.lev.values):
    varInterp = Ngl.vinth2p(DS[varName].values,hyam,hybm,pressGoals,PS,1,p0mb,1,True)
## Handle data that's by-plume for EDMF output
elif np.shape(DS[varName].values)[1]==len(DS.nens.values):
    varInterp = np.full([len(DS.time.values), len(DS.nens.values),
                         len(pressGoals)], np.nan)
    
    for iEns in range(len(DS.nens.values)):
        varInterp[:,iEns,:] = Ngl.vinth2p(DS[varName].values[:,iEns,:],hyai,hybi,pressGoals,PS,1,p0mb,1,True)

# %%
len(DS.nens.values)
# Out:
# 25

# %%
def process_camData_h3(DS, DSctrl):
    
    ## Interpolate to standard levels 
    # - - - - - - - - - - - - - - - - - - - - - - - -
    print('Beginning interpolation...') 
    
    # Decide on levels to interpoalte to and add to larger arrays
    pnew64 = np.arange(200.0,980.0,10.0) 
    
    DS = DS.assign_coords({"levInterp": pnew64})
    
    varSels = np.asarray(['up_macmicAvg', 'dn_macmicAvg','upa_macmicAvg','dna_macmicAvg',
               'thlu_macmicAvg','qtu_macmicAvg','thld_macmicAvg','qtd_macmicAvg' ])
    
    for iVar in range(len(varSels)): 
        # Interpolate variables and add to larger arrays 
        interpVar_real = interpolateToPressure_v2_h3(DS, DSctrl, varSels[iVar], pnew64)

        if len(np.shape(interpVar_real))==2: 
            DS[varSels[iVar]+'_interp']  = (('time','levInterp'), interpVar_real)
        elif len(np.shape(interpVar_real))==3: 
            DS[varSels[iVar]+'_interp']  = (('time','nens','levInterp'), interpVar_real)
        elif len(np.shape(interpVar_real))==4: 
            DS[varSels[iVar]+'_interp']  = (('time','ncyc','nens','levInterp'), interpVar_real)
        
    return DS

# %%
def interpolateToPressure_v2_h3(DS, DSctrl, varName, pressGoals):
    p0mb = DSctrl.P0.values/100        # mb

    # Pull out hya/hyb profiles 
    hyam = np.squeeze(DSctrl.hyam.values)[:]
    hybm = np.squeeze(DSctrl.hybm.values)[:]
    hyai = np.squeeze(DSctrl.hyai.values)[:]
    hybi = np.squeeze(DSctrl.hybi.values)[:]

    # Surface pressure with time dimension
    PS   = DSctrl.PS.values              # Pa 

    # Converting variables: 
    if np.shape(DS[varName].values)[1]==len(DS.ilev.values):
        varInterp = Ngl.vinth2p(DS[varName].values,hyai,hybi,pressGoals,PS,1,p0mb,1,True)
    elif np.shape(DS[varName].values)[1]==len(DS.lev.values):
        varInterp = Ngl.vinth2p(DS[varName].values,hyam,hybm,pressGoals,PS,1,p0mb,1,True)
    ## Handle data that's by-plume for EDMF output
    elif np.shape(DS[varName].values)[1]==len(DS.nens.values):
        varInterp = np.full([len(DS.time.values), len(DS.nens.values),
                             len(pressGoals)], np.nan)
        
        for iEns in range(len(DS.nens.values)):
            varInterp[:,iEns,:] = Ngl.vinth2p(DS[varName].values[:,iEns,:,],hyai,hybi,pressGoals,PS,1,p0mb,1,True)
 
    ## Handle data that's by-plume *and* by subcycle for EDMF output
    elif np.shape(DS[varName].values)[2]==len(DS.nens.values):
        varInterp = np.full([len(DS.time.values), len(DS.ncyc.values), len(DS.nens.values) ,
                             len(pressGoals)], np.nan)
        
        for iEns in range(len(DS.nens.values)):
            for iCyc in range(len(DS.ncyc.values)):
                varInterp[:,iCyc,iEns,:] = Ngl.vinth2p(DS[varName].values[:,iCyc,iEns,:],hyai,hybi,pressGoals,PS,1,p0mb,1,True)

            
    saveOut = varInterp

# %%
# %% time
# plumeLabel = np.full([len(scamDS_h2.case.values), len(scamDS_h2.time.values), len(scamDS_h2.nens.values)], 'SurfaceAvg')
#
# sigDig     = 9
#
# for iCase in range(len(clmDS_h2.case.values)):
#
#     for iT in range(len(clmDS_h1.time.values)-1):
#
#         # Sel time QFLX and edmf_uplh
#         this_uplh    = scamDS_h2.isel(case=(iCase)).isel(time=iT, ilev=-1).edmf_uplh.values
#         this_qflx    = clmDS_h1.isel(case=(iCase)).isel(time=iT).QFLX
#         this_qflx_LU = clmDS_h2.isel(case=iCase).isel(time=iT).QFLX
#         this_upa     = scamDS_h2.isel(case=(iCase)).isel(time=iT, ilev=-1).edmf_upa.values
#
#         iGrass = np.where(np.around(this_uplh, sigDig) == np.around(this_qflx.values[0],sigDig))[0]
#         iCrop  = np.where(np.around(this_uplh, sigDig) == np.around(this_qflx.values[1],sigDig))[0]
#
#         # Land-unit means...
#         iUrban = np.where(np.around(this_uplh, sigDig) == np.around(this_qflx_LU.values[2],sigDig))[0]
#         iLake  = np.where(np.around(this_uplh, sigDig) == np.around(this_qflx_LU.values[3],sigDig))[0]
#
#         ## TODO: For safety, since using a round off digit, should confirm that things aren't being marked as two PFTs
#
#         ## Also fill in if the plume is not active...
#         this_upa  = scamDS_h2.isel(case=(iCase)).isel(time=iT, ilev=-1).edmf_upa.values
#         iMiss     = np.where(this_upa==0.0)[0]
#
#         plumeLabel[iCase, iT, iGrass] = 'C3grass'
#         plumeLabel[iCase, iT, iCrop]  = 'IrrigCrop'
#         plumeLabel[iCase, iT, iLake]  = 'Lake'
#         plumeLabel[iCase, iT, iUrban] = 'Urban'
#         plumeLabel[iCase, iT, iMiss]  = 'Off'
#
# scamDS_h2['plumeLabel'] = (('case','time','nens'), plumeLabel)

# %%
# %% time
# ## Get number of plumes at each time/level
# nPlumesActive = scamDS_h2.edmf_upa_interp.count(dim='nens')
# print(np.shape(nPlumesActive))
#
# scamDS['nPlumesActive'] = (('case','time','levInterp'), nPlumesActive.values)
#
# # grassDS = scamDS_h2.where(scamDS_h2.plumeLabel == 'C3grass')
# # cropDS  = scamDS_h2.where(scamDS_h2.plumeLabel == 'IrrigCrop')
# # lakeDS  = scamDS_h2.where(scamDS_h2.plumeLabel == 'Lake')
# # urbanDS = scamDS_h2.where(scamDS_h2.plumeLabel == 'Urban')
#
# scamDS['nPlumesActive_grass'] = (('case','time','levInterp'), scamDS_h2.edmf_upa_interp.where(scamDS_h2.plumeLabel == 'C3grass').count(dim='nens').values)
# scamDS['nPlumesActive_crop']  = (('case','time','levInterp'), scamDS_h2.edmf_upa_interp.where(scamDS_h2.plumeLabel == 'IrrigCrop').count(dim='nens').values)
# scamDS['nPlumesActive_urban'] = (('case','time','levInterp'), scamDS_h2.edmf_upa_interp.where(scamDS_h2.plumeLabel == 'Urban').count(dim='nens').values)
# scamDS['nPlumesActive_lake']  = (('case','time','levInterp'), scamDS_h2.edmf_upa_interp.where(scamDS_h2.plumeLabel == 'Lake').count(dim='nens').values)
